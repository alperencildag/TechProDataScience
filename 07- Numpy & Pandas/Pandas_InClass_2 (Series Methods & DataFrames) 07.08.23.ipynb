# %% [markdown]
# ![Yeni%20logo.png](attachment:Yeni%20logo.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Basic Attributes & Methods of Series

# %% [markdown]
# **SOME COMMON ATTRIBUTES** [Official Pandas API Document](https://pandas.pydata.org/docs/reference/api/pandas.Series.html)<br>
#
# **Series.values:** Serinin değerlerinin Numpy dizisi (array) olarak döndürülmesini sağlar.
#
# **Series.index:**  Serinin indekslerinin döndürülmesini sağlar.
#
# **Series.dtype:**  Serinin veri tipini döndürür.
#
# **Series.size:**   Serinin eleman sayısını döndürür.
#
# **Series.shape:**  Serinin boyutunu döndürür.
#
# **Series.ndim:**   Serinin boyut sayısını döndürür.
#
# **Series.head():** Serinin ilk n adet elemanını döndürür.
#
# **Series.tail():** Serinin son n adet elemanını döndürür.
#
# **Series.sample():** Serinin random n adet elemanını döndürür.
#
# **Series.describe():** Serinin istatistiksel özetini döndürür.
#
# **Series.sort_index:** Seriyi indexlerine göre sıralar.
#
# **Series.sort_values():** Seriyi değerlerine göre sıralar.
#
# **Series.isnull():**      Serinin her bir elemanının null (None) olup olmadığını kontrol eder.
#
# **Series.fillna():**      Null değerleri belirli bir değerle doldurur.
#
# **Series.dropna():**      Null değerleri seriden çıkarır.
#
# **Series.isin:**        Serideki öğelerin değerlerde yer alıp almadığını kontrol eder.

# %%
seri = pd.Series(np.random.randint(0,50,6))
seri
# Out:
# 0    13
# 1    42
# 2    12
# 3    13
# 4    45
# 5    15
# dtype: int32

# %%
seri.dtype
# Out:
# dtype('int32')

# %%
type(seri)
# Out:
# pandas.core.series.Series

# %%
seri.size
# Out:
# 6

# %%
len(seri)
# Out:
# 6

# %%
seri.ndim
# Out:
# 1

# %%
seri.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
seri.values
# Out:
# array([13, 42, 12, 13, 45, 15])

# %%
seri.items
# Out:
# <bound method Series.items of 0    13
# 1    42
# 2    12
# 3    13
# 4    45
# 5    15
# dtype: int32>

# %%
list(seri.items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 list(seri.items)
#
# TypeError: 'method' object is not iterable

# %%
list(seri.items())
# Out:
# [(0, 13), (1, 42), (2, 12), (3, 13), (4, 45), (5, 15)]

# %%
seri.head()   # default=5
# Out:
# 0    13
# 1    42
# 2    12
# 3    13
# 4    45
# dtype: int32

# %%
seri.head(2)
# Out:
# 0    13
# 1    42
# dtype: int32

# %%
seri.tail()   # default=5
# Out:
# 1    42
# 2    12
# 3    13
# 4    45
# 5    15
# dtype: int32

# %%
seri.tail(1)
# Out:
# 5    15
# dtype: int32

# %%
seri.sample()   # default=1
# Out:
# 2    12
# dtype: int32

# %%
seri.sample(4)
# Out:
# 2    12
# 0    13
# 1    42
# 4    45
# dtype: int32

# %%
seri.sort_index()
# Out:
# 0    13
# 1    42
# 2    12
# 3    13
# 4    45
# 5    15
# dtype: int32

# %%
seri.sort_index(ascending=False)
# Out:
# 5    15
# 4    45
# 3    13
# 2    12
# 1    42
# 0    13
# dtype: int32

# %%
seri.sort_values()
# Out:
# 2    12
# 0    13
# 3    13
# 5    15
# 1    42
# 4    45
# dtype: int32

# %%
seri.sort_values(ascending=False)
# Out:
# 4    45
# 1    42
# 5    15
# 0    13
# 3    13
# 2    12
# dtype: int32

# %%
seri
# Out:
# 0    13
# 1    42
# 2    12
# 3    13
# 4    45
# 5    15
# dtype: int32

# %%
seri.isin([13,42])
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %% [markdown]
# # DataFrames

# %% [markdown]
# ## Creating a DataFrame
#
# DataFrame, iki boyutlu bir veri koleksiyonudur.
#
# Verilerin tablo şeklinde (tabular) saklandığı bir veri yapısıdır.
#
# Veri kümeleri satırlar ve sütunlar halinde düzenlenir; veri çerçevesinde birden çok veri kümesi depolayabiliriz.
#
# DataFrame'i, aynı dizini paylaşmak için bir araya getirilmiş bir dizi Series nesnesi olarak düşünebiliriz.
#
# Veri çerçevesine sütun/satır seçimi ve sütun/satır ekleme gibi çeşitli aritmetik işlemleri gerçekleştirebiliriz.
#
# DataFrame'leri harici depolamadan içe aktarabiliriz; SQL Veritabanı, CSV dosyası ve bir Excel dosyası.
#
# [SOURCE01](https://www.tutorialspoint.com/python_pandas/python_pandas_dataframe.htm),
# [SOURCE02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html),
# [SOURCE03](https://morioh.com/p/2528ac775b1b),
# [SOURCE04](https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python),
# [SOURCE05](https://www.guru99.com/python-pandas-tutorial.html),
# [SOURCE06](https://realpython.com/pandas-dataframe/) &
# [SOURCE07](https://towardsdatascience.com/a-simple-guide-to-pandas-dataframes-b125f64e1453)<br>
# [VIDEO SOURCE01](https://www.youtube.com/watch?v=zmdjNSmRXF4),
# [VIDEO SOURCE02](https://www.youtube.com/watch?v=F6kmIpWWEdU) &
# [VIDEO SOURCE03](https://towardsdatascience.com/pandas-dataframe-basics-3c16eb35c4f3)<br>

# %% [markdown]
# ### Creating a DataFrame Using the Lists of Data & Columns

# %%
data = [[1,2,3], [4,5,6]]
columns = ["A", "B", "C"]

df = pd.DataFrame(data = data, columns = columns)
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
data = [["a",2,3.5], ["b",5,6.5]]
columns = ["A", "B", "C"]

df = pd.DataFrame(data = data, columns = columns)
df
# Out:
#    A  B    C
# 0  a  2  3.5
# 1  b  5  6.5

# %%
df.dtypes
# Out:
# A     object
# B      int64
# C    float64
# dtype: object

# %%
df.apply(type)
# Out:
# A    <class 'pandas.core.series.Series'>
# B    <class 'pandas.core.series.Series'>
# C    <class 'pandas.core.series.Series'>
# dtype: object

# %%
data = [["a",2,3.5], [1,"b",6.5]]
columns = ["A", "B", "C"]

df = pd.DataFrame(data = data, columns = columns)
df
# Out:
#    A  B    C
# 0  a  2  3.5
# 1  1  b  6.5

# %%
df.dtypes
# Out:
# A     object
# B     object
# C    float64
# dtype: object

# %% [markdown]
# ### Creating a DataFrame Using a Numpy Arrays

# %%
arr = np.arange(1,27,3).reshape(3,3)
arr
# Out:
# array([[ 1,  4,  7],
#        [10, 13, 16],
#        [19, 22, 25]])

# %%
df = pd.DataFrame(arr)
df
# Out:
#     0   1   2
# 0   1   4   7
# 1  10  13  16
# 2  19  22  25

# %%
df = pd.DataFrame(data = arr, columns=["A1", "A2", "A3"])
df
# Out:
#    A1  A2  A3
# 0   1   4   7
# 1  10  13  16
# 2  19  22  25

# %%
df = pd.DataFrame(data = arr, columns=["A1", "A2", "A3"], index=["B1", "B2", "B3"])
df
# Out:
#     A1  A2  A3
# B1   1   4   7
# B2  10  13  16
# B3  19  22  25

# %%
df = pd.DataFrame(arr, ["B1", "B2", "B3"], ["A1", "A2", "A3"])
df
# Out:
#     A1  A2  A3
# B1   1   4   7
# B2  10  13  16
# B3  19  22  25

# %%
df = pd.DataFrame(arr, ["A1", "A2", "A3"], ["B1", "B2", "B3"])
df
# Out:
#     B1  B2  B3
# A1   1   4   7
# A2  10  13  16
# A3  19  22  25

# %% [markdown]
# ### Creating a DataFrame Using a Dictionary

# %%
data = {"Name": ["Ali", "Veli", "Mehmet"], "Age": [20,30,40]}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Name  Age
# 0     Ali   20
# 1    Veli   30
# 2  Mehmet   40

# %% [markdown]
# ## Basic Attributes & Methods of DataFrames

# %%
df.head(2)
# Out:
#    Name  Age
# 0   Ali   20
# 1  Veli   30

# %%
df.tail(2)
# Out:
#      Name  Age
# 1    Veli   30
# 2  Mehmet   40

# %%
df.sample(2)
# Out:
#      Name  Age
# 2  Mehmet   40
# 1    Veli   30

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
[i for i in df.columns]
# Out:
# ['Name', 'Age']

# %%
for i in df.columns:
    print(i)
# Out:
# Name
# Age

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.Age
# Out:
# 0    20
# 1    30
# 2    40
# Name: Age, dtype: int64

# %%
df.Name
# Out:
# 0       Ali
# 1      Veli
# 2    Mehmet
# Name: Name, dtype: object

# %%
df.Age.mean()
# Out:
# 30.0

# %%
df.columns = ["İsim", "Yaş"]
df
# Out:
#      İsim  Yaş
# 0     Ali   20
# 1    Veli   30
# 2  Mehmet   40

# %%
df.index = ["a", "b", "c"]
df
# Out:
#      İsim  Yaş
# a     Ali   20
# b    Veli   30
# c  Mehmet   40

# %%
df.rename(columns={"İsim": "x", "Yaş": "y"})
# Out:
#         x   y
# a     Ali  20
# b    Veli  30
# c  Mehmet  40

# %%
df
# Out:
#      İsim  Yaş
# a     Ali   20
# b    Veli   30
# c  Mehmet   40

# %%
df.rename(columns={"İsim": "x", "Yaş": "y"}, inplace=True)

# %%
df
# Out:
#         x   y
# a     Ali  20
# b    Veli  30
# c  Mehmet  40

# %%
df.rename(columns={"x": "İsim", "y": "Yaş"}, inplace=2)   # 0: False, 1-2-...: True olduğundan çalışır
df
# Out:
#      İsim  Yaş
# a     Ali   20
# b    Veli   30
# c  Mehmet   40

# %%
df.shape
# Out:
# (3, 2)

# %%
df.shape[0]
# Out:
# 3

# %%
df.shape[1]
# Out:
# 2

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
df
# Out:
#      İsim  Yaş
# a     Ali   20
# b    Veli   30
# c  Mehmet   40

# %%
"İsim" in df
# Out:
# True

# %%
"Name" in df
# Out:
# False

# %%
df.İsim == "Ali"
# Out:
# a     True
# b    False
# c    False
# Name: İsim, dtype: bool

# %% [markdown]
# ![Yeni%20logo.png](attachment:Yeni%20logo.png)
